# %% [markdown]
# # Tomato Growth Measurement

# %%
data <-data.frame(day=c(0,7,12,17,20,26,28,33,37,40,46),
                  A1_PH=c(0,3,5,7,9,16,22,33,44,52,74),
                  A2_PH=c(0,3,5,7,9,18,24,34,45,53,73),
                  A3_PH=c(0,3,4,5,6,11,14,17,20,23,35),
                  A4_PH=c(0,3,5,7,8,15,20,31,41,47,64),
                  A5_PH=c(0,3,5,7,8,13,17,25,33,39,55),
                  A1_SI=c(NA,NA,2,3,4,5,6,7,9,12,19),
                  A2_SI=c(NA,NA,2,3,5,6,7,7,9,11,18),
                  A3_SI=c(NA,NA,2,2,3,3,4,5,6,8,11),
                  A4_SI=c(NA,NA,2,3,4,5,5,7,8,11,16),
                  A5_SI=c(NA,NA,2,3,4,4,5,6,7,9,12),
                  A1_LI=c(0,2,6,8,14,21,26,39,65,88,108),
                  A2_LI=c(0,2,6,8,15,24,28,40,66,90,94),
                  A3_LI=c(0,2,6,8,10,14,17,20,30,39,56),
                  A4_LI=c(0,2,6,8,13,20,24,37,61,77,93),
                  A5_LI=c(0,2,6,8,11,17,20,30,49,65,81),
                  A1_BI=c(NA,NA,NA,NA,NA,NA,NA,NA,0,5,8),
                  A2_BI=c(NA,NA,NA,NA,NA,NA,NA,NA,0,5,8),
                  A3_BI=c(NA,NA,NA,NA,NA,NA,NA,NA,0,5,8),
                  A4_BI=c(NA,NA,NA,NA,NA,NA,NA,NA,0,5,8),
                  A5_BI=c(NA,NA,NA,NA,NA,NA,NA,NA,0,5,8))

# %%
# Growth Model
duration=46
x=seq(46,duration,by=2)

# %%
# Plant Height
plot(data$day,data$A1_PH, xlab="Day",ylab="",main="Tomato plant height", col = "black", type="b",lty=1,lwd=3)
lines(data$day,data$A2_PH, type="b",col = "green",lty=1,lwd=3)
lines(data$day,data$A3_PH, type="b",col = "blue",lty=1,lwd=3)
lines(data$day,data$A4_PH, type="b",col = "magenta",lty=1,lwd=3)
lines(data$day,data$A5_PH, type="b",col = "red",lty=1,lwd=3)
legend("topleft",c("A1","A2","A3","A4","A5"),
       lty=c(1),lwd=c(3,3,3,3,3),col=c("black","green","blue","magenta","red"))
# Out:
# Plot with title "Tomato plant height"

# %%
# Plant SI
plot(data$day,data$A1_SI, xlab="Day",ylab="",main="Tomato stems initiation", col = "black", type="b",lty=1,lwd=3)
lines(data$day,data$A2_SI, type="b",col = "green",lty=1,lwd=3)
lines(data$day,data$A3_SI, type="b",col = "blue",lty=1,lwd=3)
lines(data$day,data$A4_SI, type="b",col = "magenta",lty=1,lwd=3)
lines(data$day,data$A5_SI, type="b",col = "red",lty=1,lwd=3)
legend("topleft",c("A1","A2","A3","A4","A5"),
       lty=c(1),lwd=c(3,3,3,3,3),col=c("black","green","blue","magenta","red"))
# Out:
# Plot with title "Tomato stems initiation"

# %%
# Plant LI
plot(data$day,data$A1_LI, xlab="Day",ylab="",main="Tomato leaves initiation (n)", col = "black", type="b",lty=1,lwd=3)
lines(data$day,data$A2_LI, type="b",col = "green",lty=1,lwd=3)
lines(data$day,data$A3_LI, type="b",col = "blue",lty=1,lwd=3)
lines(data$day,data$A4_LI, type="b",col = "magenta",lty=1,lwd=3)
lines(data$day,data$A5_LI, type="b",col = "red",lty=1,lwd=3)
legend("topleft",c("A1","A2","A3","A4","A5"),
       lty=c(1),lwd=c(3,3,3,3,3),col=c("black","green","blue","magenta","red"))
# Out:
# Plot with title "Tomato leaves initiation (n)"
