# %% [markdown]
# # Convert db file to csv

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("WeatherNode.db")

# %%
df = pd.read_sql_query("select * from Weather_data;", conn)

# %%
df
# Out:
#                  timestamp  tempSHT    hum    IR  Full  Visible      Lux  \
# 0      2019-11-16 03:50:54    27.61  62.08    40   117       77   103.38
# 1      2019-11-16 12:08:12    26.75  59.69    42   124       82   110.62
# 2      2019-11-16 12:09:13    26.56  59.56    42   124       82   110.62
# 3      2019-11-16 12:10:14    26.41  59.15    43   126       83   111.54
# 4      2019-11-16 12:11:15    26.47  61.38    43   127       84   113.34
# ...                    ...      ...    ...   ...   ...      ...      ...
# 11155  2019-11-24 12:46:29    47.32  30.19  1747  4451     2704  3351.09
# 11156  2019-11-24 12:19:06    33.86  44.50    17    78       61    97.32
# 11157  2019-11-24 12:20:07    32.93  45.93    16    71       55    86.92
# 11158  2019-11-24 12:21:08    32.21  47.44    18    84       66   105.79
# 11159  2019-11-24 12:22:09    31.68  47.93    16    71       55    86.92
#
#        eCO2  TVOC  tempCCS  Pressure   altm  tempMPL
# ...

# %%
df.to_csv('Weather_data.csv')
